# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from functools import reduce
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
merge_df
# Display the data table for preview
merge_df.dtypes
# Out:
# Mouse ID               object
# Drug Regimen           object
# Sex                    object
# Age_months              int64
# Weight (g)              int64
# Timepoint               int64
# Tumor Volume (mm3)    float64
# Metastatic Sites        int64
# dtype: object

# %%
# Checking the number of mice.
mcount = merge_df['Mouse ID'].nunique()
mcount
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_df = merge_df.loc[merge_df.duplicated(subset=["Mouse ID", "Timepoint"]), "Mouse ID"].unique()
duplicate_mouse_df
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
all = merge_df[merge_df['Mouse ID'] == 'g989']
all
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merge_df.drop(labels=[908,909,910,911,912,913,914,915,916,917,918,919,920])

clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
#review data to make sure no null values
clean_df.count()
# Out:
# Mouse ID              1880
# Drug Regimen          1880
# Sex                   1880
# Age_months            1880
# Weight (g)            1880
# Timepoint             1880
# Tumor Volume (mm3)    1880
# Metastatic Sites      1880
# dtype: int64

# %%
# Checking the number of mice in the clean DataFrame.
mcount2 = clean_df['Mouse ID'].nunique()
mcount2
# Out:
# 248

# %%
#different drugs
unique_drugs = clean_df['Drug Regimen'].unique()
unique_drugs
# Out:
# array(['Ramicane', 'Capomulin', 'Infubinol', 'Placebo', 'Ceftamin',
#        'Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol'],
#       dtype=object)

# %%
#extract drug regimen and tumor volume from dataframe
short_df = clean_df[['Drug Regimen','Tumor Volume (mm3)' ]]
short_df
# Out:
#      Drug Regimen  Tumor Volume (mm3)
# 0        Ramicane           45.000000
# 1        Ramicane           38.825898
# 2        Ramicane           35.014271
# 3        Ramicane           34.223992
# 4        Ramicane           32.997729
# ...           ...                 ...
# 1888     Naftisol           63.145652
# 1889     Naftisol           65.841013
# 1890     Naftisol           69.176246
# 1891     Naftisol           70.314904
# 1892     Naftisol           73.867845
#
# [1880 rows x 2 columns]

# %%
#groupby drug regimen.  display mean of tumor volume per drug
drugs_short_df = short_df.groupby(['Drug Regimen'])

#round(drugs_short_df.mean(),3)
drugs_short_df

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

tumor_mean = drugs_short_df['Tumor Volume (mm3)'].mean()
tumor_median = drugs_short_df['Tumor Volume (mm3)'].median()
tumor_var = drugs_short_df['Tumor Volume (mm3)'].var()
tumor_stdev = drugs_short_df['Tumor Volume (mm3)'].std()
tumor_sem = drugs_short_df['Tumor Volume (mm3)'].sem()

#create dataframe
tumor_df = pd.DataFrame({'Tumor Volume Mean':tumor_mean,
                         'Tumor Volume Median':tumor_median,
                         'Tumor Volume Variance':tumor_var,
                         'Tumor Volume Standard Deviation':tumor_stdev,
                         'Tumor Volume Standard Error of the Mean':tumor_sem    
})
tumor_df
# Out:
#               Tumor Volume Mean  Tumor Volume Median  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Standard Deviation  \
# Drug Regimen
# Capomulin                            4.994774
# Ceftamin                             6.268188
# Infubinol                            6.567243
# Ketapril                             8.279709
# Naftisol                             8.134708
# Placebo                              7.821003
# Propriva                             6.622085
# Ramicane                             4.846308
# Stelasyn                             7.710419
# Zoniferol                            6.966589
#
#               Tumor Volume Standard Error of the Mean
# Drug Regimen
# Capomulin                                    0.329346
# Ceftamin                                     0.469821
# Infubinol                                    0.492236
# Ketapril                                     0.603860
# Naftisol                                     0.596466
# Placebo                                      0.581331
# Propriva                                     0.544332
# Ramicane                                     0.320955
# Stelasyn                                     0.573111
# Zoniferol                                    0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
agg_tumor_df = drugs_short_df.agg(['mean','median', 'var', 'std', 'sem'])

agg_tumor_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

drug_counts = short_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].count()
drug_counts

ax = drug_counts.plot.bar(x='Drug Regimen',y='Tumor Volume (mm3)')
ax
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
#x=short_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].count()

x_axis=np.arange(len(unique_drugs))

#print(labels)
#plt.bar(x_axis,unique_drugs)#drug_counts)
plt.bar(unique_drugs, drug_counts)
plt.xticks(unique_drugs,rotation='vertical')
plt.title("PyPlot Count of Each Drug Regimen")
plt.xlabel("Drug Name")
plt.ylabel("Count of Use for Each Drug Regimen")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

gender = clean_df.groupby(['Sex','Mouse ID']).count()
gender.groupby(['Sex']).count()

pie_gender = gender.groupby(['Sex']).count().plot(kind="pie", y='Drug Regimen',title='Female vs Male Mice',figsize=(11,6))
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
y=np.array([123,125])
gender_labels = ['Female', 'Male']
plt.pie(y, labels = gender_labels)
plt.legend(bbox_to_anchor=(1,1),title = 'Gender of Mice Within Drug Regimen:')

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# capomulin = clean_df.loc[clean_df['Drug Regimen'] == 'Capomulin',]
# capomulin
# Start by getting the last (greatest) timepoint for each mouse
gender_max_tp = clean_df.groupby(['Mouse ID'])['Timepoint'].max()
gender_max_tp

# short_df = clean_df[['Drug Regimen','Tumor Volume (mm3)' ]]
# short_df
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
last_tp_aclean_df = pd.merge(clean_df,gender_max_tp,how='left',on=['Mouse ID'])
last_tp_aclean_df.rename(columns={'Timepoint_y':'Maximum Tumor Size'})
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint_x  \
# 0        k403     Ramicane  Male          21          16            0
# 1        k403     Ramicane  Male          21          16            5
# 2        k403     Ramicane  Male          21          16           10
# 3        k403     Ramicane  Male          21          16           15
# 4        k403     Ramicane  Male          21          16           20
# ...       ...          ...   ...         ...         ...          ...
# 1875     z969     Naftisol  Male           9          30           25
# 1876     z969     Naftisol  Male           9          30           30
# 1877     z969     Naftisol  Male           9          30           35
# 1878     z969     Naftisol  Male           9          30           40
# 1879     z969     Naftisol  Male           9          30           45
#
#       Tumor Volume (mm3)  Metastatic Sites  Maximum Tumor Size
# 0              45.000000                 0                  45
# 1              38.825898                 0                  45
# 2              35.014271                 1                  45
# 3              34.223992                 1                  45
# 4              32.997729                 1                  45
# ...                  ...               ...                 ...
# 1875           63.145652                 2                  45
# 1876           65.841013                 3                  45
# 1877           69.176246                 4                  45
# 1878           70.314904                 4                  45
# 1879           73.867845                 4                  45
#
# [1880 rows x 9 columns]

# %%
last_tp_aclean_df.to_csv(index=False)
# Out:
# 'Mouse ID,Drug Regimen,Sex,Age_months,Weight (g),Timepoint_x,Tumor Volume (mm3),Metastatic Sites,Timepoint_y\r\nk403,Ramicane,Male,21,16,0,45.0,0,45\r\nk403,Ramicane,Male,21,16,5,38.82589807,0,45\r\nk403,Ramicane,Male,21,16,10,35.01427146,1,45\r\nk403,Ramicane,Male,21,16,15,34.22399174,1,45\r\nk403,Ramicane,Male,21,16,20,32.99772858,1,45\r\nk403,Ramicane,Male,21,16,25,33.46457735,1,45\r\nk403,Ramicane,Male,21,16,30,31.09949753,1,45\r\nk403,Ramicane,Male,21,16,35,26.54699343,1,45\r\nk403,Ramicane,Male,21,16,40,24.36550471,1,45\r\nk403,Ramicane,Male,21
omulin,Male,16,17,0,45.0,0,20\r\nf966,Capomulin,Male,16,17,5,38.79647373,0,20\r\nf966,Capomulin,Male,16,17,10,35.6244027,0,20\r\nf966,Capomulin,Male,16,17,15,32.62300253,0,20\r\nf966,Capomulin,Male,16,17,20,30.48598484,0,20\r\nm546,Ramicane,Male,18,16,0,45.0,0,45\r\nm546,Ramicane,Male,18,16,5,42.99887638,0,45\r\nm546,Ramicane,Male,18,16,10,43.74822357,0,45\r\nm546,Ramicane,Male,18,16,15,39.89743533,0,45\r\nm546,Ramicane,Male,18,16,20,36.71229535,0,45\r\nm546,Ramicane,Male,18,16,25,37.44444543,0,45\r\nm546,Ramicane,Male,18,16,30,37.96993365,0,45\r\nm546,Ramicane,Male,18,16,35,38.62753581,1,45\r\nm546,Ramicane,Male,18,16,40,35.114575200000004,1,45\r\nm546,Ramicane,Male,18,16,45,30.56462509,1,45\r\nz578,Ramicane,Male,11,16,0,45.0,0,45\r\nz578,Ramicane,Male,11,16,5,42.18878662,0,45\r\nz578,Ramicane,Male,11,16,10,42.95211843,0,45\r\nz578,Ramicane,Male,11,16,15,38.68851607,0,45\r\nz578,Ramicane,Male,11,16,20,36.89001635,0,45\r\nz578,Ramicane,Male,11,16,25,37.41411419,0,45\r\nz5 ...

# %%
love_mouse = last_tp_aclean_df.groupby('Mouse ID')
#love_mouse.head()
love_mouse.to_csv(index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-16bf59d64fb4> in <module>
#       1 love_mouse = last_tp_aclean_df.groupby('Mouse ID')
#       2 #love_mouse.head()
# ----> 3 love_mouse.to_csv(index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     579
#     580         raise AttributeError(
# --> 581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#     583
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_csv'

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []


# last_tp_aclean_df
# last_tp_aclean_df.rename(columns={'Timepoint_y':'Maximum Tumor Size'})

# Calculate the IQR and quantitatively determine if there are any potential outliers.    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # "Timepoint_y" = final size of tumor volume (tumor_vol_data)
drug_tv_df = last_tp_aclean_df[['Mouse ID',  "Tumor Volume (mm3)", 'Drug Regimen', 'Timepoint_y']]
drug_tv_df
#groupby mouse ID and set index
id_df = clean_df.groupby('Mouse ID')
id_df.head()
    # add subset 
#treatments  (drill down into the 4 drugs)
# mouse_id_df = drug_tv_df.set_index('Mouse ID')
# mouse_id_df

# mouse_id_df.groupby(by='Drug Regimen',as_index=True)
# mouse_id_df

# treatments_drill = drug_tv_df.groupby('Mouse ID')['Drug Regimen']
# treatments_drill.head()  


# #gender_max_tp = clean_df.groupby(['Mouse ID'])['Timepoint'].max()    
# #treatments_drill = drug_tv_df.groupby('Mouse ID')['Timepoint_y'].max()

# #treatments = drug_tv_df.groupby(['Mouse ID'#,"Tumor Volume (mm3)",'Drug Regimen'])['Timepoint_y'].max()
  
    # Determine outliers using upper and lower bounds
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1883     z969     Naftisol  Male           9          30          0
# 1884     z969     Naftisol  Male           9          30          5
# 1885     z969     Naftisol  Male           9          30         10
# 1886     z969     Naftisol  Male           9          30         15
# 1887     z969     Naftisol  Male           9          30         20
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1883           45.000000                 0
# 1884           49.332999                 0
# 1885           52.656081                 1
# 1886           54.713005                 2
# 1887           57.898778                 2
#
# [1103 rows x 8 columns]

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
