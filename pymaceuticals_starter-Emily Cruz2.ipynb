# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from functools import reduce
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merge_df = pd.merge(mouse_metadata, study_results, on="Mouse ID")
merge_df
# Display the data table for preview
merge_df.dtypes
# Out:
# Mouse ID               object
# Drug Regimen           object
# Sex                    object
# Age_months              int64
# Weight (g)              int64
# Timepoint               int64
# Tumor Volume (mm3)    float64
# Metastatic Sites        int64
# dtype: object

# %%
# Checking the number of mice.
mcount = merge_df['Mouse ID'].nunique()
mcount
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mouse_df = merge_df.loc[merge_df.duplicated(subset=["Mouse ID", "Timepoint"]), "Mouse ID"].unique()
duplicate_mouse_df
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
all = merge_df[merge_df['Mouse ID'] == 'g989']
all
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
#      Tumor Volume (mm3)  Metastatic Sites
# 908           45.000000                 0
# 909           45.000000                 0
# 910           48.786801                 0
# 911           47.570392                 0
# 912           51.745156                 0
# 913           49.880528                 0
# 914           51.325852                 1
# 915           53.442020                 0
# 916           55.326122                 1
# 917           54.657650                 1
# 918           56.045564                 1
# 919           59.082294                 1
# 920           62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = merge_df.drop(labels=[908,909,910,911,912,913,914,915,916,917,918,919,920])

clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1880 rows x 8 columns]

# %%
#review data to make sure no null values
clean_df.count()
# Out:
# Mouse ID              1880
# Drug Regimen          1880
# Sex                   1880
# Age_months            1880
# Weight (g)            1880
# Timepoint             1880
# Tumor Volume (mm3)    1880
# Metastatic Sites      1880
# dtype: int64

# %%
# Checking the number of mice in the clean DataFrame.
mcount2 = clean_df['Mouse ID'].nunique()
mcount2
# Out:
# 248

# %%
#different drugs
unique_drugs = clean_df['Drug Regimen'].unique()
unique_drugs
# Out:
# array(['Ramicane', 'Capomulin', 'Infubinol', 'Placebo', 'Ceftamin',
#        'Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol'],
#       dtype=object)

# %%
#extract drug regimen and tumor volume from dataframe
short_df = clean_df[['Drug Regimen','Tumor Volume (mm3)' ]]
short_df
# Out:
#      Drug Regimen  Tumor Volume (mm3)
# 0        Ramicane           45.000000
# 1        Ramicane           38.825898
# 2        Ramicane           35.014271
# 3        Ramicane           34.223992
# 4        Ramicane           32.997729
# ...           ...                 ...
# 1888     Naftisol           63.145652
# 1889     Naftisol           65.841013
# 1890     Naftisol           69.176246
# 1891     Naftisol           70.314904
# 1892     Naftisol           73.867845
#
# [1880 rows x 2 columns]

# %%
#groupby drug regimen.  display mean of tumor volume per drug
drugs_short_df = short_df.groupby(['Drug Regimen'])

#round(drugs_short_df.mean(),3)
drugs_short_df

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

tumor_mean = drugs_short_df['Tumor Volume (mm3)'].mean()
tumor_median = drugs_short_df['Tumor Volume (mm3)'].median()
tumor_var = drugs_short_df['Tumor Volume (mm3)'].var()
tumor_stdev = drugs_short_df['Tumor Volume (mm3)'].std()
tumor_sem = drugs_short_df['Tumor Volume (mm3)'].sem()

#create dataframe
tumor_df = pd.DataFrame({'Tumor Volume Mean':tumor_mean,
                         'Tumor Volume Median':tumor_median,
                         'Tumor Volume Variance':tumor_var,
                         'Tumor Volume Standard Deviation':tumor_stdev,
                         'Tumor Volume Standard Error of the Mean':tumor_sem    
})
tumor_df
# Out:
#               Tumor Volume Mean  Tumor Volume Median  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Standard Deviation  \
# Drug Regimen
# Capomulin                            4.994774
# Ceftamin                             6.268188
# Infubinol                            6.567243
# Ketapril                             8.279709
# Naftisol                             8.134708
# Placebo                              7.821003
# Propriva                             6.622085
# Ramicane                             4.846308
# Stelasyn                             7.710419
# Zoniferol                            6.966589
#
#               Tumor Volume Standard Error of the Mean
# Drug Regimen
# Capomulin                                    0.329346
# Ceftamin                                     0.469821
# Infubinol                                    0.492236
# Ketapril                                     0.603860
# Naftisol                                     0.596466
# Placebo                                      0.581331
# Propriva                                     0.544332
# Ramicane                                     0.320955
# Stelasyn                                     0.573111
# Zoniferol                                    0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
agg_tumor_df = drugs_short_df.agg(['mean','median', 'var', 'std', 'sem'])

agg_tumor_df
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

drug_counts = short_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].count()
drug_counts

ax = drug_counts.plot.bar(x='Drug Regimen',y='Tumor Volume (mm3)')
ax
plt.show()

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
#x=short_df.groupby(['Drug Regimen'])['Tumor Volume (mm3)'].count()

x_axis=np.arange(len(unique_drugs))

#print(labels)
#plt.bar(x_axis,unique_drugs)#drug_counts)
plt.bar(unique_drugs, drug_counts)
plt.xticks(unique_drugs,rotation='vertical')
plt.title("PyPlot Count of Each Drug Regimen")
plt.xlabel("Drug Name")
plt.ylabel("Count of Use for Each Drug Regimen")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

gender = clean_df.groupby(['Sex','Mouse ID']).count()
gender.groupby(['Sex']).count()

pie_gender = gender.groupby(['Sex']).count().plot(kind="pie", y='Drug Regimen',title='Female vs Male Mice',figsize=(11,6))
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
y=np.array([123,125])
gender_labels = ['Female', 'Male']
plt.pie(y, labels = gender_labels)
plt.legend(bbox_to_anchor=(1,1),title = 'Gender of Mice Within Drug Regimen:')

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# meds = ('Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin')
# med_eval = clean_df.loc[clean_df['Drug Regimen'].isin(meds)]
# med_eval

# %%
# Start by getting the last (greatest) timepoint for each mouse
# max_tv_df = med_eval.group_by(med_eval['Mouse ID']).agg({'Timepoint':['max']})
# max_tv_df.columns = ['Timepoint']
# max_tv_df

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# capomulin = clean_df.loc[clean_df['Drug Regimen'] == 'Capomulin',]
# capomulin
# Start by getting the last (greatest) timepoint for each mouse
#gender_max_tp = clean_df.groupby(['Mouse ID'], as_index=False)['Timepoint'].max()#['Tumor Volume(mm3)']
#gender_max_tp({'max':clean_df.groupby(['Mouse ID'].)size()}).reset_index()
gender_max_tp= clean_df.groupby(["Mouse ID"]).size().to_frame(name = 'max').reset_index()
# gender_max_tp

# all_types_gender = gender_max_tp.to_frame([['Tumor Volume (mm3)']])
# all_types_gender
#clean_df5= gender_max_tp.to_frame()

#clean_df5

gender_max_tp
# Out:
#     Mouse ID  max
# 0       a203   10
# 1       a251   10
# 2       a262   10
# 3       a275   10
# 4       a366    7
# ..       ...  ...
# 243     z435    3
# 244     z578   10
# 245     z581   10
# 246     z795   10
# 247     z969   10
#
# [248 rows x 2 columns]

# %%
# mouse_ready = gender_max_tp.series([gender_max_tp],name='Final Time Point')
# mouse_ready.to_frame()

# %%
# clean_df['gender_map_tp'] = gender_max_tp
# clean_df.head(50)
last_tp_clean_df = clean_df
last_tp_clean_df.head(50)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
# 20     x401    Capomulin  Female          16          15          0
# 21     x401    Capomulin  Female          16          15          5
# 22     x401    Capomulin  Female          16          15         10
# 23     x401    Capomulin  Female          16          15         15
# 24     x401    Capomulin  Female          16          15         20
# 25     x401    Capomulin  Female          16          15         25
# 26     x401    Capomulin  Female          16          15         30
# 27     x401    Capomulin  Female          16          15         35
# 28     x401    Capomulin  Female          16          15         40
# 29     x401    Capomulin  Female          16          15         45
# 30     m601    Capomulin    Male          22          17          0
# 31     m601    Capomulin    Male          22          17          5
# 32     m601    Capomulin    Male          22          17         10
# 33     m601    Capomulin    Male          22          17         15
# 34     m601    Capomulin    Male          22          17         20
# 35     m601    Capomulin    Male          22          17         25
# 36     m601    Capomulin    Male          22          17         30
# 37     m601    Capomulin    Male          22          17         35
# 38     m601    Capomulin    Male          22          17         40
# 39     m601    Capomulin    Male          22          17         45
# 40     g791     Ramicane    Male          11          16          0
# 41     g791     Ramicane    Male          11          16          5
# 42     g791     Ramicane    Male          11          16         10
# 43     g791     Ramicane    Male          11          16         15
# 44     g791     Ramicane    Male          11          16         20
# 45     g791     Ramicane    Male          11          16         25
# 46     g791     Ramicane    Male          11          16         30
# 47     g791     Ramicane    Male          11          16         35
# 48     g791     Ramicane    Male          11          16         40
# 49     g791     Ramicane    Male          11          16         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            45.000000                 0
# 1            38.825898                 0
# 2            35.014271                 1
# 3            34.223992                 1
# 4            32.997729                 1
# 5            33.464577                 1
# 6            31.099498                 1
# 7            26.546993                 1
# 8            24.365505                 1
# 9            22.050126                 1
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0
# 15           33.949940                 0
# 16           32.959671                 1
# 17           28.328531                 1
# 18           25.472143                 1
# 19           23.343598                 1
# 20           45.000000                 0
# 21           45.473753                 0
# 22           39.113891                 0
# 23           39.776250                 0
# 24           36.065835                 0
# 25           36.617120                 0
# 26           32.915292                 0
# 27           30.206825                 0
# 28           28.167397                 0
# 29           28.484033                 0
# 30           45.000000                 0
# 31           41.408591                 1
# 32           36.825367                 1
# 33           35.464612                 1
# 34           34.255732                 1
# 35           33.118756                 1
# 36           31.758275                 1
# 37           30.834357                 1
# 38           31.378045                 1
# 39           28.430964                 1
# 40           45.000000                 0
# 41           45.851531                 0
# 42           40.170558                 0
# 43           40.678129                 0
# 44           41.211897                 0
# 45           35.569399                 1
# 46           34.952583                 1
# 47           30.960392                 1
# 48           31.369406                 1
# 49           29.128472                 1

# %%
final_timepoint = last_tp_clean_df.rename(columns={'gender_map_tp':'Final Time Point', 
                                            'Timepoint_x':'Initial Time Point'})
final_timepoint.head(50)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# 13     s185    Capomulin  Female           3          17         15
# 14     s185    Capomulin  Female           3          17         20
# 15     s185    Capomulin  Female           3          17         25
# 16     s185    Capomulin  Female           3          17         30
# 17     s185    Capomulin  Female           3          17         35
# 18     s185    Capomulin  Female           3          17         40
# 19     s185    Capomulin  Female           3          17         45
# 20     x401    Capomulin  Female          16          15          0
# 21     x401    Capomulin  Female          16          15          5
# 22     x401    Capomulin  Female          16          15         10
# 23     x401    Capomulin  Female          16          15         15
# 24     x401    Capomulin  Female          16          15         20
# 25     x401    Capomulin  Female          16          15         25
# 26     x401    Capomulin  Female          16          15         30
# 27     x401    Capomulin  Female          16          15         35
# 28     x401    Capomulin  Female          16          15         40
# 29     x401    Capomulin  Female          16          15         45
# 30     m601    Capomulin    Male          22          17          0
# 31     m601    Capomulin    Male          22          17          5
# 32     m601    Capomulin    Male          22          17         10
# 33     m601    Capomulin    Male          22          17         15
# 34     m601    Capomulin    Male          22          17         20
# 35     m601    Capomulin    Male          22          17         25
# 36     m601    Capomulin    Male          22          17         30
# 37     m601    Capomulin    Male          22          17         35
# 38     m601    Capomulin    Male          22          17         40
# 39     m601    Capomulin    Male          22          17         45
# 40     g791     Ramicane    Male          11          16          0
# 41     g791     Ramicane    Male          11          16          5
# 42     g791     Ramicane    Male          11          16         10
# 43     g791     Ramicane    Male          11          16         15
# 44     g791     Ramicane    Male          11          16         20
# 45     g791     Ramicane    Male          11          16         25
# 46     g791     Ramicane    Male          11          16         30
# 47     g791     Ramicane    Male          11          16         35
# 48     g791     Ramicane    Male          11          16         40
# 49     g791     Ramicane    Male          11          16         45
#
#     Tumor Volume (mm3)  Metastatic Sites
# 0            45.000000                 0
# 1            38.825898                 0
# 2            35.014271                 1
# 3            34.223992                 1
# 4            32.997729                 1
# 5            33.464577                 1
# 6            31.099498                 1
# 7            26.546993                 1
# 8            24.365505                 1
# 9            22.050126                 1
# 10           45.000000                 0
# 11           43.878496                 0
# 12           37.614948                 0
# 13           38.177232                 0
# 14           36.866876                 0
# 15           33.949940                 0
# 16           32.959671                 1
# 17           28.328531                 1
# 18           25.472143                 1
# 19           23.343598                 1
# 20           45.000000                 0
# 21           45.473753                 0
# 22           39.113891                 0
# 23           39.776250                 0
# 24           36.065835                 0
# 25           36.617120                 0
# 26           32.915292                 0
# 27           30.206825                 0
# 28           28.167397                 0
# 29           28.484033                 0
# 30           45.000000                 0
# 31           41.408591                 1
# 32           36.825367                 1
# 33           35.464612                 1
# 34           34.255732                 1
# 35           33.118756                 1
# 36           31.758275                 1
# 37           30.834357                 1
# 38           31.378045                 1
# 39           28.430964                 1
# 40           45.000000                 0
# 41           45.851531                 0
# 42           40.170558                 0
# 43           40.678129                 0
# 44           41.211897                 0
# 45           35.569399                 1
# 46           34.952583                 1
# 47           30.960392                 1
# 48           31.369406                 1
# 49           29.128472                 1

# %%
 # short_df = clean_df[['Drug Regimen','Tumor Volume (mm3)' ]]
 # short_df
 # Merge this group df with the original dataframe to get the tumor volume at the last timepoint
last_tp_aclean_df = pd.merge(clean_df,gender_max_tp,how='left',on=['Mouse ID'])
final_df = last_tp_aclean_df.rename(columns={'Timepoint_y':'Final Time Point', 
                                             'Timepoint_x':'Initial Time Point'})
final_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1875     z969     Naftisol  Male           9          30         25
# 1876     z969     Naftisol  Male           9          30         30
# 1877     z969     Naftisol  Male           9          30         35
# 1878     z969     Naftisol  Male           9          30         40
# 1879     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites  max
# 0              45.000000                 0   10
# 1              38.825898                 0   10
# 2              35.014271                 1   10
# 3              34.223992                 1   10
# 4              32.997729                 1   10
# ...                  ...               ...  ...
# 1875           63.145652                 2   10
# 1876           65.841013                 3   10
# 1877           69.176246                 4   10
# 1878           70.314904                 4   10
# 1879           73.867845                 4   10
#
# [1880 rows x 9 columns]

# %%
mouse_group = final_df.groupby(['Mouse ID'])
mouse_group.head()
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1870     z969     Naftisol  Male           9          30          0
# 1871     z969     Naftisol  Male           9          30          5
# 1872     z969     Naftisol  Male           9          30         10
# 1873     z969     Naftisol  Male           9          30         15
# 1874     z969     Naftisol  Male           9          30         20
#
#       Tumor Volume (mm3)  Metastatic Sites  max
# 0              45.000000                 0   10
# 1              38.825898                 0   10
# 2              35.014271                 1   10
# 3              34.223992                 1   10
# 4              32.997729                 1   10
# ...                  ...               ...  ...
# 1870           45.000000                 0   10
# 1871           49.332999                 0   10
# 1872           52.656081                 1   10
# 1873           54.713005                 2   10
# 1874           57.898778                 2   10
#
# [1103 rows x 9 columns]

# %%
# Put treatments into a list for for loop (and later for plot labels)
treatments = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol_data = []

 # Locate the rows which contain mice on each drug and get the tumor volumes 
    #(groupby)

for x in treatments:
    tv_drug = final_df[['Mouse ID','Tumor Volume (mm3)', 'Final Time Point', 'Drug Regimen']].loc[final_df['Drug Regimen'] == x]
    tv_drug.head(200)
    #tumor_vol_data.append(tv_drug)
    
        
    print(tv_drug)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-c170c69abb3d> in <module>
#       9
#      10 for x in treatments:
# ---> 11     tv_drug = final_df[['Mouse ID','Tumor Volume (mm3)', 'Final Time Point', 'Drug Regimen']].loc[final_df['Drug Regimen'] == x]
#      12     tv_drug.head(200)
#      13     #tumor_vol_data.append(tv_drug)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1644             if not (self.name == "loc" and not raise_missing):
#    1645                 not_found = list(set(key) - set(ax))
# -> 1646                 raise KeyError(f"{not_found} not in index")
#    1647
#    1648             # we skip the warning on Categorical/Interval
#
# KeyError: "['Final Time Point'] not in index"

# %%
fish = "halibut"

# Loop through each letter in the string
# and push to an array
letters = []
for letter in fish:
    letters.append(letter)

print(letters)

# %%
# Write a function that returns the arithmetic average for a list of numbers
def average(numbers):
    length = len(numbers)
    total = 0.0
    for number in numbers:
        total += number
    return total / length


# Test your function with the following:
print(average([1, 5, 9]))
print(average(range(11)))

# %%
# Calculate the IQR and quantitatively determine if there are any potential outliers.    
    # Locate the rows which contain mice on each drug and get the tumor volumes

# %%
# add subset 
#treatments  (drill down into the 4 drugs)
  
    # Determine outliers using upper and lower bounds

# %%
# last_tp_aclean_df
# last_tp_aclean_df.rename(columns={'Timepoint_y':'Maximum Tumor Size'})

# %%
capomulin_df = final_df.loc[final_df['Drug Regimen'] == 'Capomulin',: ]
ramicane_df = final_df.loc[final_df['Drug Regimen'] == 'Ramicane',:]
infubinol_df = final_df.loc[final_df['Drug Regimen']  == 'Infubinol',:]
ceftamin_df = final_df.loc[final_df['Drug Regimen'] == 'Ceftamin',:]
ceftamin_df

# %%
gender = clean_df.groupby(['Sex','Mouse ID']).count()
final_last_tp_aclean_df = last_tp_aclean_df.groupby.last
final_last_tp_aclean_df

# %%
drug_merge = clean_df.concat(['capomulin_df','ramicane_df', 'infubinol_df', 'ceftamin_df'], ignore_index = True)
drug_merge

# %%
gender_max_tp = clean_df.groupby(['Mouse ID'])['Timepoint'].max()    
gender_max_tp

# %%
# mouse_id_df = drug_tv_df.set_index('Mouse ID')
# mouse_id_df

# mouse_id_df.groupby(by='Drug Regimen',as_index=True)
# mouse_id_df

# treatments_drill = drug_tv_df.groupby('Mouse ID')['Drug Regimen']
# treatments_drill.head()  



# #treatments_drill = drug_tv_df.groupby('Mouse ID')['Timepoint_y'].max()

# #treatments = drug_tv_df.groupby(['Mouse ID'#,"Tumor Volume (mm3)",'Drug Regimen'])['Timepoint_y'].max()

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

# %%
#final_df.to_csv(r'data\all_mouse_metadata2.csv', index = False)
